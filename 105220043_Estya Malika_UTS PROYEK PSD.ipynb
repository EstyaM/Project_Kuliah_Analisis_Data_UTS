# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data_sayuran.csv")
#menampilkan data awal dan akhir 
df
# Out:
#     id  kode_provinsi nama_provinsi      komoditi  produksi_sayuran_buah  \
# 0    1             32    JAWA BARAT   BAWANG DAUN              1407997.0
# 1    2             32    JAWA BARAT  BAWANG MERAH              1734632.0
# 2    3             32    JAWA BARAT  BAWANG PUTIH                66977.0
# 3    4             32    JAWA BARAT         BAYAM               289870.0
# 4    5             32    JAWA BARAT        BLEWAH                 8748.0
# ..  ..            ...           ...           ...                    ...
# 74  75             32    JAWA BARAT      SEMANGKA                68409.0
# 75  76             32    JAWA BARAT      STROBERI                64575.0
# 76  77             32    JAWA BARAT        TERUNG               999581.0
# 77  78             32    JAWA BARAT         TOMAT              2923088.0
# 78  79             32    JAWA BARAT        WORTEL              1351166.0
#
#      satuan  tahun
# 0   KUINTAL   2019
# 1   KUINTAL   2019
# 2   KUINTAL   2019
# ...

# %%
#mengatahui 10 data terakhir 
df.tail(10)
# Out:
#     id  kode_provinsi nama_provinsi     komoditi  produksi_sayuran_buah  \
# 69  70             32    JAWA BARAT        LOBAK                    NaN
# 70  71             32    JAWA BARAT        MELON                10285.0
# 71  72             32    JAWA BARAT     MENTIMUN              1482725.0
# 72  73             32    JAWA BARAT      PAPRIKA                43729.0
# 73  74             32    JAWA BARAT  PETSAI/SAWI              1889439.0
# 74  75             32    JAWA BARAT     SEMANGKA                68409.0
# 75  76             32    JAWA BARAT     STROBERI                64575.0
# 76  77             32    JAWA BARAT       TERUNG               999581.0
# 77  78             32    JAWA BARAT        TOMAT              2923088.0
# 78  79             32    JAWA BARAT       WORTEL              1351166.0
#
#      satuan  tahun
# 69  KUINTAL   2021
# 70  KUINTAL   2021
# 71  KUINTAL   2021
# 72  KUINTAL   2021
# 73  KUINTAL   2021
# 74  KUINTAL   2021
# 75  KUINTAL   2021
# ...

# %%
 #mengetahui matrix data
df.shape
# Out:
# (79, 7)

# %%
#mendeskripsi data
df.describe()
# Out:
#               id  kode_provinsi  produksi_sayuran_buah        tahun
# count  79.000000           79.0           7.700000e+01    79.000000
# mean   40.000000           32.0           1.227558e+06  2020.012658
# std    22.949219            0.0           2.065296e+06     0.824212
# min     1.000000           32.0           0.000000e+00  2019.000000
# 25%    20.500000           32.0           1.772080e+05  2019.000000
# 50%    40.000000           32.0           8.757550e+05  2020.000000
# 75%    59.500000           32.0           1.670077e+06  2021.000000
# max    79.000000           32.0           1.740456e+07  2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     79 non-null     int64
#  1   kode_provinsi          79 non-null     int64
#  2   nama_provinsi          79 non-null     object
#  3   komoditi               79 non-null     object
#  4   produksi_sayuran_buah  77 non-null     float64
#  5   satuan                 79 non-null     object
#  6   tahun                  79 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 4.4+ KB

# %%
df['komoditi'].unique()
# Out:
# array(['BAWANG DAUN', 'BAWANG MERAH', 'BAWANG PUTIH', 'BAYAM', 'BLEWAH',
#        'BUNCIS', 'CABAI BESAR', 'CABAI RAWIT', 'JAMUR', 'KACANG MERAH',
#        'KACANG PANJANG', 'KANGKUNG', 'KEMBANG KOL', 'KENTANG', 'KETIMUN',
#        'KUBIS', 'LABU SIAM', 'LOBAK', 'MELON', 'PAPRIKA', 'PETSAI/SAWI',
#        'SEMANGKA', 'STROBERI', 'TERUNG', 'TOMAT', 'WORTEL',
#        'CABAI KERITING', 'MENTIMUN'], dtype=object)

# %%
df['tahun'].unique()
# Out:
# array([2019, 2020, 2021])

# %%
#mengetahui bnyak data kosong sebelum dilakukan prepocessing dengan mendrop data
df.isnull().sum()
# Out:
# id                       0
# kode_provinsi            0
# nama_provinsi            0
# komoditi                 0
# produksi_sayuran_buah    2
# satuan                   0
# tahun                    0
# dtype: int64

# %%
#dilakukan preprocessing dengan mendrop nilai "nan" untuk mengatasi missing value pada data
df=df.dropna()

# %%
#menampilkan data yang sudah di lakukan prepocessing 
df.isna().sum()
# Out:
# id                       0
# kode_provinsi            0
# nama_provinsi            0
# komoditi                 0
# produksi_sayuran_buah    0
# satuan                   0
# tahun                    0
# dtype: int64

# %%
#melihat distribusi atribut tunggal atau hubungan 2 atribut data
sns.pairplot(df)

# %%
#Menampilkan data dalam bentuk tabel 
fig, ax = plt.subplots(figsize=(9, 9)) 
ax.set_title('Hasil Panen Sayur dan Buah') 
ax.set_xlabel('tahun')
ax.set_ylabel('produksi_sayuran_buah')

x=df['tahun']
y=df['produksi_sayuran_buah']

plt.bar(x,y)
# Out:
# <BarContainer object of 77 artists>

# %%
#Menggambarkan variasi dalam distribusi data
print(df['produksi_sayuran_buah'].describe())
sns.distplot(df['produksi_sayuran_buah'], color='g', bins=25, hist_kws={'alpha': 0.4});
# Out:
# count    7.700000e+01
# mean     1.227558e+06
# std      2.065296e+06
# min      0.000000e+00
# 25%      1.772080e+05
# 50%      8.757550e+05
# 75%      1.670077e+06
# max      1.740456e+07
# Name: produksi_sayuran_buah, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Menampilkan data dalam bentuk boxplot agar mudah mengetahui outlier dan lainnya
sns.boxplot(data=df[['produksi_sayuran_buah']])

# %%
#Mencari Outlier 
def iqr_outlier(data,alpha):
  q75, q25 = np.percentile(data, [75 ,25])
  iqr = q75 - q25
  upperbound=q75+(iqr*alpha)
  lowerbound=q25-(iqr*alpha)
  return upperbound,lowerbound

# %%
#Mencari nilai Upperbound dan Lowerbound
u_produksi_sayuran_buah,l_produksi_sayuran_buah=iqr_outlier(df['produksi_sayuran_buah'],alpha=1.5)
print(u_produksi_sayuran_buah,l_produksi_sayuran_buah)
# Out:
# 3909380.5 -2062095.5

# %%
#Menampilkan data yang berada diantara upperbound dan lowerbound
df[
    (df['produksi_sayuran_buah']>u_produksi_sayuran_buah) |
    (df['produksi_sayuran_buah']<l_produksi_sayuran_buah)
]
# Out:
#    id  kode_provinsi nama_provinsi komoditi  produksi_sayuran_buah   satuan  \
# 8   9             32    JAWA BARAT    JAMUR             17404562.0  KUINTAL
#
#    tahun
# 8   2019

# %%
df2=pd.read_csv('data_panen.csv')

# %%
df2.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    luas_panen  satuan  tahun
# 0        47.0  HEKTAR   2013
# 1        18.0  HEKTAR   2013
# 2       409.0  HEKTAR   2013
# 3       601.0  HEKTAR   2013
# 4       161.0  HEKTAR   2013

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   243 non-null    int64
#  1   kode_provinsi        243 non-null    int64
#  2   nama_provinsi        243 non-null    object
#  3   kode_kabupaten_kota  243 non-null    int64
#  4   nama_kabupaten_kota  243 non-null    object
#  5   luas_panen           243 non-null    float64
#  6   satuan               243 non-null    object
#  7   tahun                243 non-null    int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 15.3+ KB

# %%
#Menampilkan data dalam bentuk boxplot agar mudah mengetahui outlier dan lainnya
sns.boxplot(data=df2[['luas_panen']])

# %%
#Mencari Outlier 
def iqr_outlier(data,alpha):
  q75, q25 = np.percentile(data, [75 ,25])
  iqr = q75 - q25
  upperbound=q75+(iqr*alpha)
  lowerbound=q25-(iqr*alpha)
  return upperbound,lowerbound

# %%
#Mencari nilai Upperbound dan Lowerbound
u_luas_panen,l_luas_panen=iqr_outlier(df2['luas_panen'],alpha=1.5)
print(u_luas_panen,l_luas_panen)
# Out:
# 211.1875 -126.71249999999999

# %%
#Menampilkan data yang berada diantara upperbound dan lowerbound
df2[
    (df2['luas_panen']>u_luas_panen) |
    (df2['luas_panen']<l_luas_panen)
]
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 29    30             32    JAWA BARAT                 3203
# 30    31             32    JAWA BARAT                 3204
# 31    32             32    JAWA BARAT                 3205
# 41    42             32    JAWA BARAT                 3215
# 56    57             32    JAWA BARAT                 3203
# 57    58             32    JAWA BARAT                 3204
# 66    67             32    JAWA BARAT                 3213
# 83    84             32    JAWA BARAT                 3203
# 84    85             32    JAWA BARAT                 3204
# 85    86             32    JAWA BARAT                 3205
# 93    94             32    JAWA BARAT                 3213
# 110  111             32    JAWA BARAT                 3203
# 111  112             32    JAWA BARAT                 3204
# ...

# %%
df2['tahun'].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])
